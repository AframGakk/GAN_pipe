# %%
import soundfile as sf
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %%
data, samplerate = sf.read('../../Data/kicks/WRLD-Kick-3-G.wav')
data = data[:10000]

# %%
plt.plot(data, '-')
plt.show()

# %%
plt.figure(figsize=(16, 4))
plt.plot(data[:1000], '.'); plt.plot(data[:1000], '-');

# %%
import IPython.display as ipd  # To play sound in the notebook
fname = '../../Data/kicks/WRLD-Kick-3-G.wav'   # Kick
ipd.Audio(fname)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/x-wav;base64,..." type="audio/x-wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
import os

kick_dir = '../../Data/kicks'
kick_list = os.listdir(kick_dir)
kick_list
# Out:
# ['WRLD-Kick-1-D.wav',
#  'WRLD-Kick-3-G.wav',
#  'WRLD-Kick-5-A.wav',
#  '.DS_Store',
#  'WRLD-Kick-2-F.wav',
#  'WRLD-Kick-6-B.wav',
#  'WRLD-Kick-4-G.wav']

# %%
np_kick = []
samplerate_list = []
for kick in kick_list:
    if kick == '.DS_Store':
        continue
    data, samplerate = sf.read(kick_dir + '/' + kick)
    np_kick = np.append(np_kick, np.array(data))
    samplerate_list.append(samplerate)

# %%
np_kick.shape
# Out:
# (453600,)

# %%
train = pd.read_csv('../../Data/train.csv')

# %%
train.to_numpy()
# Out:
# array([['00044347.wav', 'Hi-hat', 0],
#        ['001ca53d.wav', 'Saxophone', 1],
#        ['002d256b.wav', 'Trumpet', 0],
#        ...,
#        ['fff44ac6.wav', 'Laughter', 0],
#        ['fff6a13d.wav', 'Chime', 0],
#        ['fff81f55.wav', 'Cough', 1]], dtype=object)

# %%
submission = pd.read_csv('../../Data/sample_submission.csv')

# %%
submission.to_numpy()
# Out:
# array([['00063640.wav', 'Laughter Hi-Hat Flute'],
#        ['0013a1db.wav', 'Laughter Hi-Hat Flute'],
#        ['002bb878.wav', 'Laughter Hi-Hat Flute'],
#        ...,
#        ['ffeba2cd.wav', 'Laughter Hi-Hat Flute'],
#        ['fff6d073.wav', 'Laughter Hi-Hat Flute'],
#        ['fff8d22d.wav', 'Laughter Hi-Hat Flute']], dtype=object)
